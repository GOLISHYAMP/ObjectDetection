# %% [markdown]
# ### Followed this Documentation of tensorflow to do the following task.
# https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/training.html

# %%
import tensorflow as tf
print(tf.__version__)

# %%
# !pip install numpy==1.24.3
# !pip install protobuf==3.20.3
# !pip install tensorflow==2.14.0

# %%
import tensorflow as tf
print(tf.__version__)

# %%
pwd

# %%
# !git clone https://github.com/tensorflow/models.git

# %%
pwd

# %%
cd /kaggle/working/models/research

# %%
# From within /kaggle/working/models/research/
# !protoc object_detection/protos/*.proto --python_out=.

# %%
pwd

# %%
# From within /kaggle/working/models/research/
# !git clone https://github.com/cocodataset/cocoapi.git

# %%
cd cocoapi/PythonAPI

# %%
# !make

# %%
cp -r pycocotools /kaggle/working/models/research

# %%
pwd

# %%
cd ../..

# %%
# From within /kaggle/working/models/research/
# !cp object_detection/packages/tf2/setup.py .

# %%
# cd models/research

# %%
# !python -m pip install .

# %%
# # This Colab requires a recent numpy version.
# !pip install numpy==1.24.3
# !pip install protobuf==3.20.3
# !pip install tensorflow==2.17.1

# %%
pwd

# %%
# From within TensorFlow/models/research/
# !python object_detection/builders/model_builder_tf2_test.py

# %% [markdown]
# ## Till here the setup is done

# %% [markdown]
# Attach this dataset<br>
# https://www.kaggle.com/datasets/mbkinaci/fruit-images-for-object-detection

# %% [markdown]
# These file are used in the object detection task
#
# /kaggle/working/models/research/object_detection/export_tflite_graph_tf2.py
# /kaggle/working/models/research/object_detection/exporter_main_v2.py
# /kaggle/working/models/research/object_detection/model_main_tf2.py

# %% [markdown]
# ## Lets create the folder structure
# /kaggle/working<br>
# -->trainingDemo<br>
# ---->annotations<br>
# ---->exported_models<br>
# ---->images<br>
# ------>Train<br>
# ------>Test<br>
# ---->models<br>
# ---->pre-trained-models<br>

# %%
cd ../..

# %%
pwd

# %%
# !mkdir trainingDemo

# %%
cd trainingDemo

# %%
mkdir annotations exported_models images models pre-trained-models

# %%
cp -r /kaggle/input/fruit-images-for-object-detection/train_zip/train /kaggle/working/trainingDemo/images

# %%
cp -r /kaggle/input/fruit-images-for-object-detection/test_zip/test /kaggle/working/trainingDemo/images

# %% [markdown]
# ## Dataset in include in the folder structure

# %%
pwd

# %%
cd pre-trained-models

# %% [markdown]
# ### Pick the model which ever you like from here
# https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz

# %%
# !tar -xvf ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz

# %%
pwd

# %%
cd ../annotations

# %%
cp /kaggle/input/label-map/label_map.pbtxt .

# %%
# !cat label_map.pbtxt

# %%
cd ..

# %% [markdown]
# ## Download the generate_tfrecord.py from here
#
# https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/_downloads/da4babe668a8afb093cc7776d7e630f3/generate_tfrecord.py

# %%
cp /kaggle/input/generate-tf-record-for-cvt-xml-to-tfrecords/generate_tfrecord.py .

# %%
pwd

# %%
# Create train data:
# !python generate_tfrecord.py -x /kaggle/working/trainingDemo/images/train -l /kaggle/working/trainingDemo/annotations/label_map.pbtxt -o /kaggle/working/trainingDemo/annotations/train.record

# %%
# Create test data:
# !python generate_tfrecord.py -x /kaggle/working/trainingDemo/images/test -l /kaggle/working/trainingDemo/annotations/label_map.pbtxt -o /kaggle/working/trainingDemo/annotations/test.record

# %%
pwd

# %%
cd models

# %%
mkdir my_ssd_resnet101_model

# %%
cp /kaggle/input/pipeline-config-file/pipeline.config /kaggle/working/trainingDemo/models/my_ssd_resnet101_model

# %% [markdown]
# ### Trianing the model

# %%
pwd

# %%
cd ..

# %%
# !cp /kaggle/working/models/research/object_detection/export_tflite_graph_tf2.py .
# !cp /kaggle/working/models/research/object_detection/exporter_main_v2.py .
# !cp /kaggle/working/models/research/object_detection/model_main_tf2.py .

# %%
tf.__version__

# %%
pip install --upgrade tensorflow-estimator
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python /kaggle/working/trainingDemo/model_main_tf2.py --model_dir=/kaggle/working/trainingDemo/models/my_ssd_resnet101_model --pipeline_config_path=/kaggle/working/trainingDemo/models/my_ssd_resnet101_model/pipeline.config
# Out:
# 2025-01-19 14:08:51.460431: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737295731.480444     394 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737295731.486571     394 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Traceback (most recent call last):
#   File "/kaggle/working/trainingDemo/model_main_tf2.py", line 31, in <module>
#     from object_detection import model_lib_v2
#   File "/usr/local/lib/python3.10/dist-packages/object_detection/model_lib_v2.py", line 30, in <module>
#     from object_detection import inputs
# ...

# %%
# !python -m ipykernel install --user --name=py39_env --display-name "Python 3.9 (py39_env)"
# Out:
# Installed kernelspec py39_env in /root/.local/share/jupyter/kernels/py39_env

# %%
# !sudo apt-get install python3.9
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.9-minimal libpython3.9-stdlib mailcap mime-support
#   python3.9-minimal
# Suggested packages:
#   python3.9-venv binfmt-support
# The following NEW packages will be installed:
#   libpython3.9-minimal libpython3.9-stdlib mailcap mime-support python3.9
#   python3.9-minimal
# 0 upgraded, 6 newly installed, 0 to remove and 62 not upgraded.
# Need to get 4,874 kB of archives.
# After this operation, 19.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 mailcap all 3.70+nmu1ubuntu1 [23.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 mime-support all 3.66 [3,696 B]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.9-minimal amd64 3.9.21-1+jammy1 [837 kB]
# ...

# %%
# !python -m ipykernel install --user --name=py39_env --display-name "Python 3.9 (py39_env)"
# Out:
# Installed kernelspec py39_env in /root/.local/share/jupyter/kernels/py39_env

# %%
# !python --version
# Out:
# Python 3.10.12
